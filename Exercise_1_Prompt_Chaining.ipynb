# %%
# MOCK PROMPT CHAIN

# -------------------------
# STEP 1: CLASSIFY ISSUE
# -------------------------
user_message = "My internet keeps disconnecting every 5 minutes."
step1_output = "Technical Issue"  # This is what an AI *might* respond

print("STEP 1 OUTPUT:", step1_output)

# -------------------------
# STEP 2: ASK FOR MISSING INFO
# -------------------------
step2_output = "Could you tell me if the issue happens on all devices or just one?"

print("\nSTEP 2 OUTPUT:", step2_output)

# -------------------------
# STEP 3: PROVIDE SOLUTION
# -------------------------
user_details = "It happens on all devices."
step3_output = """
Thanks for the details! Since the issue affects all devices, please try restarting your router.
If the problem continues, I can escalate this to a network specialist for deeper investigation.
"""

print("\nSTEP 3 OUTPUT:", step3_output)
# Out:
# STEP 1 OUTPUT: Technical Issue
#
# STEP 2 OUTPUT: Could you tell me if the issue happens on all devices or just one?
#
# STEP 3 OUTPUT:
# Thanks for the details! Since the issue affects all devices, please try restarting your router.
# If the problem continues, I can escalate this to a network specialist for deeper investigation.

# %% [markdown]
# # Exercise 1
#
# ## Tools Used
# - Google Colab (no API key needed)
# -   prompt chaining (simulated outputs)
#
# ## Step 1 Prompt — Classify Issue
# "You are a customer support classifier. Classify the user's message into one of these categories:
# - Billing
# - Technical Issue
# - Account Access
# - Product Question
# - Other
# Return ONLY the category."
#
# ## Step 2 Prompt — Ask for Missing Info
# "You are a customer support assistant. Based on the issue category, ask the user for any missing information needed to resolve the issue. Keep the question short and polite."
#
# ## Step 3 Prompt — Provide Solution
# "You are a senior support agent. Given the issue category and user details, provide:
# 1. A clear solution if possible
# 2. If not solvable, an escalation message
# Keep the tone friendly and professional."
#
# ## How the Chain Works
# - Step 1 classifies the issue.
# - Step 2 uses the category from Step 1 to ask for missing info.
# - Step 3 uses the category + user details to generate a solution.
